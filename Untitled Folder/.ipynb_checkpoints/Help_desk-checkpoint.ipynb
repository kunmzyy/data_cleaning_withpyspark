# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\User\\Desktop\\10alytics\\Spark\\spark\\Untitled Folder'

# %%
Tickets_df= pd.read_csv('helpdesk_tickets.csv')

# %%
Tickets_df
# Out:
#      Ticket Number        Date Created  \
# 0           111636 2021-03-12 09:57:00
# 1           111632 2021-03-10 16:21:00
# 2           111621 2021-02-22 12:08:00
# 3           111608 2021-02-15 11:41:00
# 4           111596 2021-01-22 10:58:00
# ..             ...                 ...
# 560         111543 2020-10-27 08:23:00
# 561         111531 2020-10-09 11:57:00
# 562         111481 2020-08-11 09:53:00
# 563         111515 2020-09-30 22:44:00
# 564         111400 2020-03-11 18:17:00
#
#                                               Subject             From  \
# 0                Error Displaying in Different Module      Jasper John
# 1                             Approval Workflow Error      Erick White
# 2       Public IP Trusted Certificate Authority Error    Tomi Yamamoto
# 3                                       JDE Slowdown   Riza Richardson
# 4                                       JDE Slow Down  Riza Richardson
# ...

# %%
Tickets_df.dtypes.info
# Out:
# <bound method Series.info of Ticket Number                    int64
# Date Created                    object
# Subject                         object
# From                            object
# From Email                      object
# Priority                        object
# Department                      object
# Type                            object
# Source                          object
# Current Status                  object
# Last Updated                    object
# Due Date                        object
# Overdue                          int64
# Answered                         int64
# Agent Assigned                  object
# Team Lead                      float64
# Team Assigned                   object
# Thread Count                     int64
# Attachment Count                 int64
# Category                        object
# Issue Origin                    object
# Select Ticket Status Update     object
# Unnamed: 22                    float64
# ...

# %%
Tickets_df['Date Created']=pd.to_datetime(Tickets_df['Date Created'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15012\212562317.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   Tickets_df['Date Created']=pd.to_datetime(Tickets_df['Date Created'])

# %%
Tickets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 565 entries, 0 to 564
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Ticket Number                565 non-null    int64
#  1   Date Created                 565 non-null    datetime64[ns]
#  2   Subject                      565 non-null    object
#  3   From                         565 non-null    object
#  4   From Email                   565 non-null    object
#  5   Priority                     565 non-null    object
#  6   Department                   565 non-null    object
#  7   Type                         563 non-null    object
#  8   Source                       565 non-null    object
#  9   Current Status               565 non-null    object
#  10  Last Updated                 565 non-null    object
#  11  Due Date                     460 non-null    datetime64[ns]
# ...

# %%
Tickets_df['Due Date']= pd.to_datetime(Tickets_df['Due Date'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15012\30546599.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   Tickets_df['Due Date']= pd.to_datetime(Tickets_df['Due Date'])

# %%
Tickets_df['Last Upadted']=pd.to_datetime(Tickets_df['Last Updated'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15012\397638700.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   Tickets_df['Last Upadted']=pd.to_datetime(Tickets_df['Last Updated'])

# %%
Tickets_df['Unnamed: 22'].fillna('Unknown', inplace= True)

# %%
Tickets_df.rename(columns={'Unnamed: 22':'Unknown1','From': ' Full_name', 'From Email': 'Email'})
# Out:
#      Ticket Number        Date Created  \
# 0           111636 2021-03-12 09:57:00
# 1           111632 2021-03-10 16:21:00
# 2           111621 2021-02-22 12:08:00
# 3           111608 2021-02-15 11:41:00
# 4           111596 2021-01-22 10:58:00
# ..             ...                 ...
# 560         111543 2020-10-27 08:23:00
# 561         111531 2020-10-09 11:57:00
# 562         111481 2020-08-11 09:53:00
# 563         111515 2020-09-30 22:44:00
# 564         111400 2020-03-11 18:17:00
#
#                                               Subject        Full_name  \
# 0                Error Displaying in Different Module      Jasper John
# 1                             Approval Workflow Error      Erick White
# 2       Public IP Trusted Certificate Authority Error    Tomi Yamamoto
# 3                                       JDE Slowdown   Riza Richardson
# 4                                       JDE Slow Down  Riza Richardson
# ...

# %%
##How many tickets were opened and closed?
##What is the average resolution time for tickets?
##Which agent has the highest and lowest ticket closure rate?
##How many tickets are currently open?

# %%
Tickets_df.groupby('Current Status')['Date Created'].count()
# Out:
# Current Status
# Closed      484
# Open         66
# Resolved     15
# Name: Date Created, dtype: int64
